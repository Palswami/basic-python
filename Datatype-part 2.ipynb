# %% [markdown]
# # List operation
# 1.1 Append

# %%
# alwayes add an element/ at the end of list

# %%
languages=['cpp','java','c#']

# %%
languages.append('python')

# %%
languages
# Out:
# ['cpp', 'java', 'c#', 'python']

# %% [markdown]
# # insert
#  * insert the element at specific index

# %%
languages.insert(2,'ruby')

# %%
languages
# Out:
# ['cpp', 'java', 'ruby', 'c#', 'python']

# %%
languages.insert(-1,'perl')

# %%
languages
# Out:
# ['cpp', 'java', 'ruby', 'c#', 'perl', 'python']

# %%
help(list.insert)
# Out:
# Help on method_descriptor:
#
# insert(...)
#     L.insert(index, object) -- insert object before index

# %% [markdown]
# # 1.3 Remove

# %%
languages.remove('perl')

# %%
languages
# Out:
# ['cpp', 'java', 'ruby', 'c#', 'python']

# %%
languages.remove('Java')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-524bfd36003a> in <module>
# ----> 1 languages.remove('Java')
#
# ValueError: list.remove(x): x not in list

# %% [markdown]
# # 1.4 Pop

# %%
languages
# Out:
# ['cpp', 'java', 'ruby', 'c#', 'python']

# %%
languages.pop(1)
# Out:
# 'java'

# %%
languages
# Out:
# ['cpp', 'ruby', 'c#', 'python']

# %%
languages.pop(2)
# Out:
# 'c#'

# %%
languages
# Out:
# ['cpp', 'ruby', 'python']

# %%
languages.pop()
# Out:
# 'python'

# %%
languages
# Out:
# ['cpp', 'ruby']

# %% [markdown]
# # 1.5 Del keyword

# %%
languages.append('html')

# %%
languages
# Out:
# ['cpp', 'ruby', 'html']

# %%
languages.append('css')

# %%
languages
# Out:
# ['cpp', 'ruby', 'html', 'css']

# %%
del languages[2]

# %%
languages
# Out:
# ['cpp', 'ruby', 'css']

# %%
del languages[:1]

# %%
languages
# Out:
# ['ruby', 'css']

# %%
languages.append('pascal')

# %%
languages
# Out:
# ['ruby', 'css', 'pascal']

# %%
languages.append('javascript')

# %%
languages
# Out:
# ['ruby', 'css', 'pascal', 'javascript']

# %%
languages.append('vc')

# %%
languages
# Out:
# ['ruby', 'css', 'pascal', 'javascript', 'vc']

# %%
del languages[1:3]

# %%
languages
# Out:
# ['ruby', 'javascript', 'vc']

# %%
del languages[0:4:5]

# %%
languages
# Out:
# ['javascript', 'vc']

# %% [markdown]
# #  Append using list

# %%
languages
# Out:
# ['javascript', 'vc']

# %%
numlist=[100,200,300]

# %%
len(numlist)
# Out:
# 3

# %%
languages.append(numlist)

# %%
languages
# Out:
# ['javascript', 'vc', 'numlist', [100, 200, 300]]

# %%
languages.remove('numlist')

# %%
languages
# Out:
# ['javascript', 'vc', [100, 200, 300]]

# %%
len(languages)
# Out:
# 3

# %%
languages[-1]
# Out:
# [100, 200, 300]

# %%
languages[-1][-1]
# Out:
# 300

# %%
languages
# Out:
# ['javascript', 'vc', [100, 200, 300]]

# %%
s='WELCOME'

# %%
languages.append(s)

# %%
languages
# Out:
# ['javascript', 'vc', [100, 200, 300], 'WELCOME']

# %% [markdown]
# # extend
# * extend the list of the container passed

# %%
languages
# Out:
# ['javascript', 'vc', [100, 200, 300], 'WELCOME']

# %%
another=['tcs','wipro',]

# %%
another
# Out:
# ['tcs', 'wipro']

# %%
languages.extend(another)

# %%
languages
# Out:
# ['javascript', 'vc', [100, 200, 300], 'WELCOME', 'tcs', 'wipro']

# %%
len(languages)
# Out:
# 6

# %%
s
# Out:
# 'WELCOME'

# %%
languages.extend(s)

# %%
languages
# Out:
# ['javascript',
#  'vc',
#  [100, 200, 300],
#  'WELCOME',
#  'tcs',
#  'wipro',
#  'W',
#  'E',
#  'L',
#  'C',
#  'O',
#  'M',
#  'E']

# %%
another
# Out:
# ['tcs', 'wipro']

# %%
languages.extend(another[1])

# %%
languages
# Out:
# ['javascript',
#  'vc',
#  [100, 200, 300],
#  'WELCOME',
#  'tcs',
#  'wipro',
#  'W',
#  'E',
#  'L',
#  'C',
#  'O',
#  'M',
#  'E',
#  'w',
#  'i',
#  'p',
#  'r',
#  'o']

# %% [markdown]
# # Count

# %%
languages.count('wipro')
# Out:
# 1

# %%
languages.count('c')
# Out:
# 0

# %%
languages.count(100)
# Out:
# 0

# %%
languages.count('w')
# Out:
# 1

# %% [markdown]
# # Indexing

# %%
languages
# Out:
# ['javascript',
#  'vc',
#  [100, 200, 300],
#  'WELCOME',
#  'tcs',
#  'wipro',
#  'W',
#  'E',
#  'L',
#  'C',
#  'O',
#  'M',
#  'E',
#  'w',
#  'i',
#  'p',
#  'r',
#  'o']

# %%
languages.index('tcs')
# Out:
# 4

# %%
languages.index('w',1)
# Out:
# 13

# %% [markdown]
# # Mutable vs immutable

# %%
s
# Out:
# 'WELCOME'

# %%
languages
# Out:
# ['javascript',
#  'vc',
#  [100, 200, 300],
#  'WELCOME',
#  'tcs',
#  'wipro',
#  'W',
#  'E',
#  'L',
#  'C',
#  'O',
#  'M',
#  'E',
#  'w',
#  'i',
#  'p',
#  'r',
#  'o']

# %%
languages=['python','perl','ruby']

# %%
languages
# Out:
# ['python', 'perl', 'ruby']

# %%
languages[0]='ruby'

# %%
languages
# Out:
# ['ruby', 'perl', 'ruby']

# %%
s[0]='z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-ab471980a0a4> in <module>
# ----> 1 s[0]='z'
#
# TypeError: 'str' object does not support item assignment

# %%
s='ZELCOME'

# %%
s
# Out:
# 'ZELCOME'

# %%
a='python'

# %%
a
# Out:
# 'python'

# %%
id(a)
# Out:
# 140317824519112

# %%
a= 'java'

# %%
a
# Out:
# 'java'

# %%
id(a)
# Out:
# 140317824777776

# %%
# muitable:List,dict,set
#immutable:string,int,float,tuple,bool

# %% [markdown]
# # Sort

# %%
languages
# Out:
# ['ruby', 'perl', 'ruby']

# %%
languages.sort()

# %%
languages
# Out:
# ['perl', 'ruby', 'ruby']

# %%
languages.append('ibm')

# %%
languages.append('gic')

# %%
languages
# Out:
# ['perl', 'ruby', 'ruby', 'ibm', 'gic']

# %%
languages.sort()

# %%
languages
# Out:
# ['gic', 'ibm', 'perl', 'ruby', 'ruby']

# %% [markdown]
# # reverse

# %%
languages.reverse()

# %%
languages
# Out:
# ['ruby', 'ruby', 'perl', 'ibm', 'gic']

# %% [markdown]
# ######

# %% [markdown]
# # Tuples
# * ordered collection of item/element
# * syntax
# * immutable

# %%
vaccines = ('covaxin','cowishild','sputnik')

# %%
vaccines
# Out:
# ('covaxin', 'cowishild', 'sputnik')

# %%
print(type(vaccines))
# Out:
# <class 'tuple'>

# %%
len(vaccines)
# Out:
# 3

# %%
vaccines[0]
# Out:
# 'covaxin'

# %%
vaccines[-1]
# Out:
# 'sputnik'

# %%
vaccines[0:2]
# Out:
# ('covaxin', 'cowishild')

# %%
vaccines.count('covaxin')
# Out:
# 1

# %%
del vaccines[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-127-eb854b664376> in <module>
# ----> 1 del vaccines[1]
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# #  packing

# %%
rs ='swami',21,'MUM'

# %%
rs
# Out:
# ('swami', 21, 'MUM')

# %%
print(type(rs))
# Out:
# <class 'tuple'>

# %%
name,age,team = 'rohit',34,'ban'

# %%
name
# Out:
# 'rohit'

# %%
age
# Out:
# 34

# %%
team
# Out:
# 'ban'

# %%
*name,age,team = 'rohit',34,'ban','india'

# %%
name
# Out:
# ['rohit', 34]

# %%
**name,age,team = 'rohit',34,'ban','india'
# Out:
#   File "<ipython-input-142-43835d719254>", line 1
#     **name,age,team = 'rohit',34,'ban','india'
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# # List in tuple

# %%
player=('virat','rohit',[1,2,3])

# %%
player
# Out:
# ('virat', 'rohit', [1, 2, 3])

# %%
player[2]
# Out:
# [1, 2, 3]

# %%
player[0]
# Out:
# 'virat'

# %%
player[2].append(4)

# %%
player
# Out:
# ('virat', 'rohit', [1, 2, 3, 4])

# %%
player[3].append('kohli')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-151-73ee88d9c332> in <module>
# ----> 1 player[3].append('kohli')
#
# IndexError: tuple index out of range

# %% [markdown]
# # In operator

# %%
'virat' in player
# Out:
# True

# %%
'dhoni' in player
# Out:
# False

# %%
languages
# Out:
# ['ruby', 'ruby', 'perl', 'ibm', 'gic']

# %%
'ruby' not in languages
# Out:
# False

# %% [markdown]
# # Misc-string

# %%
location="C:\\newfolder"

# %%
print(location)
# Out:
# C:\newfolder

# %%
location=r"C:\newfolder"

# %%
print(location)
# Out:
# C:\newfolder

# %% [markdown]
# # Format

# %%
sessioncount=10
chapter=8

# %%
print(sessioncount)
# Out:
# 10

# %%
print(chapter)
# Out:
# 8

# %%
msg="ther will be " + str(chapter) + "chapter in the cource,spand acrose" + str(sessioncount) + "session"

# %%
msg
# Out:
# 'ther will be 8chapter in the cource,spand acrose10session'

# %%
fmsg="ther will be {} chapter in the cource,spand acrose {} session"

# %%
fmsg
# Out:
# 'ther will be {} chapter in the cource,spand acrose {} session'
